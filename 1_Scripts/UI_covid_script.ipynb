# %% [markdown]
# **Op-Ed Article: Covid's Next Problem** <br>
# *Jake Schneider & Peter McKelvey* <br>
# May 2020

# %% [markdown]
# ----

# %% [markdown]
# **Load Libraries**

# %%
#Import libraries
import sys
import pandas as pd
from datetime import date, datetime, time, timedelta
import pendulum
import json
import requests
import numpy as np
import math

import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style='ticks', context='talk')

from matplotlib.offsetbox import AnchoredText
from sklearn import linear_model
from sklearn.metrics import r2_score
import statsmodels.api as sm
#import fbprophet

import statistics 
from statistics import mode 

from collections import OrderedDict 

import warnings
import itertools

from matplotlib.backends.backend_pdf import PdfPages
from fpdf import FPDF
from PIL import Image

# %% [markdown]
# ----

# %% [markdown]
# **Load Data**

# %%
# Load Data from SHED Survey
# Data available from: https://www.federalreserve.gov/consumerscommunities/shed_data.htm

shed_df = pd.read_csv('../2_Inputs/SHED Data/publicApril2020_revised.csv')

# %%
# View SHED Data

shed_df.head()
# Out:
#    CASEID    weight                  B2 EF3_a EF3_b EF3_c EF3_d EF3_e EF3_f  \
# 0       1  0.551009          Doing okay    No    No   Yes    No    No    No
# 1       2  0.831331          Doing okay   Yes    No   Yes    No    No    No
# 2       3  1.435291          Doing okay    No   Yes   Yes    No    No    No
# 3       4  0.602249  Living comfortably   Yes    No    No    No    No    No
# 4       5  0.826866     Just getting by    No    No   Yes    No    No    No
#
#   EF3_g  ...                                             pprent  \
# 0    No  ...  Owned or being bought by you or someone in you...
# 1    No  ...  Owned or being bought by you or someone in you...
# 2    No  ...  Owned or being bought by you or someone in you...
# 3    No  ...  Owned or being bought by you or someone in you...
# 4    No  ...  Owned or being bought by you or someone in you...
#
#                          ppwork ppnet ppt01 ppt1317 ppt18ov ppt25 ppt612  \
# 0         Not working - retired     9     0       0       3     0      0
# 1  Working - as a paid employee     9     0       1       2     0      1
# 2         Not working - retired     9     0       0       1     0      0
# 3       Working - self-employed     9     0       0       2     0      0
# 4       Working - self-employed     9     0       0       4     0      0
#
#   SSTNO                                               ind1
# 0    70                                                 -2
# 1    70  Utilities, Waste Management, and Remediation S...
# 2    70                                                 -2
# 3    70  Community/Non-Profit Organizations (including ...
# 4    70                                      Manufacturing
#
# [5 rows x 58 columns]

# %%
# View working variable 'ppwork'

shed_df['ppwork'].head()
# Out:
# 0           Not working - retired
# 1    Working - as a paid employee
# 2           Not working - retired
# 3         Working - self-employed
# 4         Working - self-employed
# Name: ppwork, dtype: object

# %% [markdown]
# ----

# %%
# Create variables for working from 'ppwork'

working = shed_df.loc[(shed_df['ppwork'] == 'Working - as a paid employee') | (shed_df['ppwork'] == 'Working - self-employed')]
working.head()
# Out:
#    CASEID    weight                  B2 EF3_a EF3_b EF3_c EF3_d EF3_e EF3_f  \
# 1       2  0.831331          Doing okay   Yes    No   Yes    No    No    No
# 3       4  0.602249  Living comfortably   Yes    No    No    No    No    No
# 4       5  0.826866     Just getting by    No    No   Yes    No    No    No
# 5       6  0.957646  Living comfortably   Yes    No   Yes    No    No    No
# 7       8  1.311333          Doing okay   Yes    No   Yes    No    No    No
#
#   EF3_g  ...                                             pprent  \
# 1    No  ...  Owned or being bought by you or someone in you...
# 3    No  ...  Owned or being bought by you or someone in you...
# 4    No  ...  Owned or being bought by you or someone in you...
# 5    No  ...  Owned or being bought by you or someone in you...
# 7    No  ...  Owned or being bought by you or someone in you...
#
#                          ppwork ppnet ppt01 ppt1317 ppt18ov ppt25 ppt612  \
# 1  Working - as a paid employee     9     0       1       2     0      1
# 3       Working - self-employed     9     0       0       2     0      0
# 4       Working - self-employed     9     0       0       4     0      0
# 5  Working - as a paid employee     9     0       0       5     0      0
# 7  Working - as a paid employee     9     0       0       3     0      0
#
#   SSTNO                                               ind1
# 1    70  Utilities, Waste Management, and Remediation S...
# 3    70  Community/Non-Profit Organizations (including ...
# 4    70                                      Manufacturing
# 5    70                            Repairs and Maintenance
# 7    70                  Health Care and Social Assistance
#
# [5 rows x 58 columns]

# %%
# Create variables for laid_off from 'ppwork'

laid_off = shed_df.loc[(shed_df['ppwork'] == 'Not working - on temporary layoff from a job') | (shed_df['ppwork'] == 'Not working - looking for work')]
laid_off.head()
# Out:
#      CASEID    weight                  B2    EF3_a    EF3_b    EF3_c    EF3_d  \
# 8         9  1.025913          Doing okay       No       No      Yes       No
# 151     152  1.024331          Doing okay       No       No      Yes       No
# 191     192  0.816090     Just getting by       No      Yes      Yes       No
# 214     215  1.018425  Living comfortably  Refused  Refused  Refused  Refused
# 241     242  2.267510          Doing okay       No       No      Yes       No
#
#        EF3_e    EF3_f    EF3_g  ...  \
# 8         No       No       No  ...
# 151       No       No       No  ...
# 191       No       No       No  ...
# 214  Refused  Refused  Refused  ...
# 241       No       No       No  ...
#
#                                                 pprent  \
# 8                                      Rented for cash
# 151  Owned or being bought by you or someone in you...
# 191  Owned or being bought by you or someone in you...
# 214  Owned or being bought by you or someone in you...
# 241  Owned or being bought by you or someone in you...
#
#                              ppwork ppnet ppt01 ppt1317 ppt18ov ppt25 ppt612  \
# 8    Not working - looking for work     9     0       0       1     0      0
# 151  Not working - looking for work     9     0       1       6     0      0
# 191  Not working - looking for work     9     0       0       2     0      0
# 214  Not working - looking for work     9     0       0       1     0      0
# 241  Not working - looking for work     9     0       0      12     0      0
#
#     SSTNO ind1
# 8      70   -2
# 151    70   -2
# 191    70   -2
# 214    70   -2
# 241    70   -2
#
# [5 rows x 58 columns]

# %%
# Create variable for laid_off_with_other from 'ppwork'

laid_off_with_other = shed_df.loc[(shed_df['ppwork'] == 'Not working - on temporary layoff from a job') | (shed_df['ppwork'] == 'Not working - looking for work') | (shed_df['ppwork'] == 'Not working - other')]
laid_off_with_other.head()
# Out:
#      CASEID    weight                  B2 EF3_a EF3_b EF3_c EF3_d EF3_e EF3_f  \
# 8         9  1.025913          Doing okay    No    No   Yes    No    No    No
# 36       37  0.844489          Doing okay    No    No   Yes    No    No    No
# 85       86  0.452383          Doing okay    No   Yes    No    No    No    No
# 91       92  0.771401          Doing okay   Yes    No    No    No    No    No
# 113     114  0.931940  Living comfortably    No    No   Yes    No    No    No
#
#     EF3_g  ...                                             pprent  \
# 8      No  ...                                    Rented for cash
# 36     No  ...  Owned or being bought by you or someone in you...
# 85     No  ...                                    Rented for cash
# 91     No  ...  Owned or being bought by you or someone in you...
# 113    No  ...  Owned or being bought by you or someone in you...
#
#                              ppwork ppnet ppt01 ppt1317 ppt18ov ppt25 ppt612  \
# 8    Not working - looking for work     9     0       0       1     0      0
# 36              Not working - other     9     0       0       3     0      0
# 85              Not working - other     9     0       0       4     0      0
# 91              Not working - other     9     0       2       2     0      1
# 113             Not working - other     9     0       2       2     1      3
#
#     SSTNO ind1
# 8      70   -2
# 36     70   -2
# 85     70   -2
# 91     70   -2
# 113    70   -2
#
# [5 rows x 58 columns]

# %%
# Confirm group totals are correct

print('Total Working', working['CASEID'].count())
print('Total Laid Off:', laid_off['CASEID'].count())
print('Total Laid Off (With Other):', laid_off_with_other['CASEID'].count())
# Out:
# Total Working 632
# Total Laid Off: 46
# Total Laid Off (With Other): 113

# %%
# Create function for most common observation

def most_common(List): 
    return(mode(List))

# %%
# Print average income of groups

print('Most Frequent Working Group Income:', most_common(working['ppincimp']))
print('Most Frequent Laid Off Group Income:', most_common(laid_off['ppincimp']))
print('Most Frequent Laif Off With Other Group Income:', most_common(laid_off_with_other['ppincimp']))
# Out:
# Most Frequent Working Group Income: $100,000 to $124,999
# Most Frequent Laid Off Group Income: $50,000 to $59,999
# Most Frequent Laif Off With Other Group Income: $50,000 to $59,999

# %%
# Create a function to count the number of items

def count_elements(seq) -> dict:
    """Tally elements from `seq`."""
    hist = {}
    for i in seq:
        hist[i] = hist.get(i, 0) + 1
    return hist

# %%
# Count Working

working_counts = count_elements(working['ppincimp'])
working_counts
# Out:
# {'$40,000 to $49,999': 29,
#  '$100,000 to $124,999': 96,
#  '$200,000 to $249,999': 28,
#  '$75,000 to $84,999': 50,
#  '$60,000 to $74,999': 53,
#  '$250,000 or more': 34,
#  '$125,000 to $149,999': 55,
#  '$175,000 to $199,999': 41,
#  '$25,000 to $29,999': 19,
#  '$30,000 to $34,999': 20,
#  '$150,000 to $174,999': 61,
#  '$85,000 to $99,999': 50,
#  '$50,000 to $59,999': 40,
#  '$35,000 to $39,999': 17,
#  '$20,000 to $24,999': 16,
#  '$12,500 to $14,999': 3,
#  '$15,000 to $19,999': 8,
#  'Less than $5,000': 4,
#  '$5,000 to $7,499': 3,
#  '$7,500 to $9,999': 2,
#  '$10,000 to $12,499': 3}

# %%
# Count Laid_Off

laid_off_counts = count_elements(laid_off['ppincimp'])
laid_off_counts
# Out:
# {'$25,000 to $29,999': 1,
#  '$60,000 to $74,999': 3,
#  '$20,000 to $24,999': 2,
#  '$250,000 or more': 2,
#  '$35,000 to $39,999': 3,
#  '$15,000 to $19,999': 2,
#  '$75,000 to $84,999': 5,
#  '$85,000 to $99,999': 3,
#  '$100,000 to $124,999': 2,
#  '$40,000 to $49,999': 3,
#  '$125,000 to $149,999': 2,
#  'Less than $5,000': 4,
#  '$200,000 to $249,999': 1,
#  '$7,500 to $9,999': 2,
#  '$10,000 to $12,499': 1,
#  '$30,000 to $34,999': 1,
#  '$50,000 to $59,999': 6,
#  '$5,000 to $7,499': 1,
#  '$175,000 to $199,999': 1,
#  '$150,000 to $174,999': 1}

# %%
counts_df = pd.DataFrame({
    'working_counts': working_counts,
    'laid_off_counts': laid_off_counts,
    'legend': [11,15,19,12,13,20,16,18,9,8,17,14,12,10,7,5,6,1,2,3,4]
    }, index=working_counts.keys())
counts_df = counts_df.sort_values(by = ['legend'])
counts_df
# Out:
#                       working_counts  laid_off_counts  legend
# Less than $5,000                   4              4.0       1
# $5,000 to $7,499                   3              1.0       2
# $7,500 to $9,999                   2              2.0       3
# $10,000 to $12,499                 3              1.0       4
# $12,500 to $14,999                 3              NaN       5
# $15,000 to $19,999                 8              2.0       6
# $20,000 to $24,999                16              2.0       7
# $30,000 to $34,999                20              1.0       8
# $25,000 to $29,999                19              1.0       9
# $35,000 to $39,999                17              3.0      10
# $40,000 to $49,999                29              3.0      11
# $50,000 to $59,999                40              6.0      12
# $75,000 to $84,999                50              5.0      12
# $60,000 to $74,999                53              3.0      13
# $85,000 to $99,999                50              3.0      14
# $100,000 to $124,999              96              2.0      15
# $125,000 to $149,999              55              2.0      16
# $150,000 to $174,999              61              1.0      17
# $175,000 to $199,999              41              1.0      18
# $200,000 to $249,999              28              1.0      19
# $250,000 or more                  34              2.0      20

# %%
ax = sns.barplot(x=counts_df.index, y=counts_df['working_counts'], palette="Blues_d")
plt.show()

#fig, ax1 = plt.subplots(figsize=(10, 10))
#tidy = counts_df.melt(id_vars=counts_df.index).rename(columns=str.title)
#sns.barplot(x=counts_df.index, y='Value', hue='Less than $5,000', data=tidy, ax=ax1)
#sns.despine(fig)

#plt.bar(working_counts.keys(), working_counts.values(), width, color='g')
#plt.show()

# %%
# data to plot
n_groups = 21
working = counts_df['working_counts']
laid_off = counts_df['laid_off_counts']

# create plot
fig, ax = plt.subplots(figsize=(10, 10.5))
index = np.arange(n_groups)
bar_width = 1.0
opacity = 0.3
opacity1 = 0.5

rects1 = plt.bar(index + bar_width, working, bar_width,
alpha=opacity,
color='b',
label='Working')

rects2 = plt.bar(index + bar_width, laid_off, bar_width,
alpha=opacity1,
color='r',
label='Laid Off')

#plt.xlabel('Income Range')
plt.ylabel('Frequency')
plt.title('Annual Income for Working and Laid Off Americans, April 2020')
plt.xticks(index + bar_width, counts_df.index, rotation = 90)
#plt.text(0, 0, t, style='oblique', ha = 'center', va = 'top', wrap = True)
plt.legend()

plt.annotate("Source: April 2020 Supplement to the 2019 SHED Survey from the US Federal Reserve Board & Authors' Calculation",
            xy=(1.0, -0.85),
            xycoords='axes fraction',
            horizontalalignment='right',
            verticalalignment='center',
            size = 10)

plt.tight_layout()
sns.despine()
plt.savefig('../3_Outputs/Annual Income Chart May 2020.jpg', dpi=300, bbox_inches='tight')
plt.show()
